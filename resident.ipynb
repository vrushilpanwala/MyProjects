# %% [markdown]
# # Predicting in this project
# 1. Tax Efficiency Index -: It capture the efficiency of converting income into tax.
# 2. Migration - Driven Tax change (AGI = Adjust gross income) -: It will predict the taxes increase or not based on migration .
# 3. cluster locations by fiscal behaviour

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Residence_tax.csv")

# %%
df.head()
# Out:
#    Tax Year          Resident Type Place of Residence       Country  \
# 0      2012  Full-Year Nonresident            Ireland       Ireland
# 1      2012  Full-Year Nonresident            Ireland       Ireland
# 2      2012  Full-Year Nonresident            Ireland       Ireland
# 3      2012  Full-Year Nonresident       A.P.O./F.P.O  A.P.O./F.P.O
# 4      2012  Full-Year Nonresident       A.P.O./F.P.O  A.P.O./F.P.O
#
#             State          County     Income Class Disclosure  \
# 0  Not Applicable  Not Applicable  40,000 - 49,999         d/
# 1  Not Applicable  Not Applicable  50,000 - 59,999         d/
# 2  Not Applicable  Not Applicable  60,000 - 74,999         d/
# 3             All             All      Under 5,000        NaN
# 4             All             All    5,000 - 9,999        NaN
#
#    Number of All Returns  NY AGI of All Returns (in thousands) *  \
# 0                    NaN                                     NaN
# ...
